# %%
import json
import requests

# %%
url = "https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_week.geojson"
response = requests.get(url)
response.json()
# Out:
# {'type': 'FeatureCollection',
#  'metadata': {'generated': 1602114560000,
#   'url': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_week.geojson',
#   'title': 'USGS All Earthquakes, Past Week',
#   'status': 200,
#   'api': '1.10.3',
#   'count': 3377},
#  'features': [{'type': 'Feature',
#    'properties': {'mag': 1.3,
#     'place': '135 km NW of Yakutat, Alaska',
#     'time': 1602114009306,
#     'updated': 1602114219476,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020cx3y31e',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak020cx3y31e.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 26,
#     'net': 'ak',
#     'code': '020cx3y31e',
#     'ids': ',ak020cx3y31e,',
#     'sources': ',ak,',
#     'types': ',origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.49,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 135 km NW of Yakutat, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-141.7041, 60.2496, 0]},
#    'id': 'ak020cx3y31e'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.63,
#     'place': '6km NW of The Geysers, CA',
#     'time': 1602113842560,
#     'updated': 1602113941160,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73468031',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73468031.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 6,
#     'net': 'nc',
#     'code': '73468031',
#     'ids': ',nc73468031,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,',
#     'nst': 20,
#     'dmin': 0.009217,
#     'rms': 0.03,
#     'gap': 44,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.6 - 6km NW of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.800499, 38.8180008, 2.48]},
#    'id': 'nc73468031'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.4,
#     'place': '32 km SE of Mina, Nevada',
#     'time': 1602113534890,
#     'updated': 1602114121468,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00777703',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00777703.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 30,
#     'net': 'nn',
#     'code': '00777703',
#     'ids': ',nn00777703,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 21,
#     'dmin': 0.012,
#     'rms': 0.1,
#     'gap': 67.56,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.4 - 32 km SE of Mina, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.8732, 38.1643, 10.2]},
#    'id': 'nn00777703'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.97,
#     'place': '24km WNW of Searles Valley, CA',
#     'time': 1602113197370,
#     'updated': 1602113421860,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39656056',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39656056.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 14,
#     'net': 'ci',
#     'code': '39656056',
#     'ids': ',ci39656056,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 18,
#     'dmin': 0.05416,
#     'rms': 0.12,
#     'gap': 81,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.0 - 24km WNW of Searles Valley, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.6285, 35.886, 5.3]},
#    'id': 'ci39656056'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.7,
#     'place': '6 km NE of Tampico, Washington',
#     'time': 1602113173470,
#     'updated': 1602114298090,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uw61691761',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/uw61691761.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 44,
#     'net': 'uw',
#     'code': '61691761',
#     'ids': ',uw61691761,',
#     'sources': ',uw,',
#     'types': ',origin,phase-data,',
#     'nst': 12,
#     'dmin': 0.1555,
#     'rms': 0.75,
#     'gap': 209,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 6 km NE of Tampico, Washington'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.807833333333, 46.578, -0.69]},
#    'id': 'uw61691761'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.68,
#     'place': '5 km S of Guánica, Puerto Rico',
#     'time': 1602111650190,
#     'updated': 1602112540112,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2020281022',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2020281022.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 110,
#     'net': 'pr',
#     'code': '2020281022',
#     'ids': ',pr2020281022,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 18,
#     'dmin': 0.0535,
#     'rms': 0.17,
#     'gap': 212,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.7 - 5 km S of Guánica, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-66.8983, 17.9251, 12]},
#    'id': 'pr2020281022'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.88,
#     'place': '6km W of Cobb, CA',
#     'time': 1602111320090,
#     'updated': 1602113046080,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73468021',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73468021.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 12,
#     'net': 'nc',
#     'code': '73468021',
#     'ids': ',nc73468021,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 8,
#     'dmin': 0.01189,
#     'rms': 0.01,
#     'gap': 91,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.9 - 6km W of Cobb, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.7906647, 38.8264999, 1.39]},
#    'id': 'nc73468021'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.85,
#     'place': '6 km SSE of Guánica, Puerto Rico',
#     'time': 1602110928010,
#     'updated': 1602111774712,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2020281021',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2020281021.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 125,
#     'net': 'pr',
#     'code': '2020281021',
#     'ids': ',pr2020281021,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 18,
#     'dmin': 0.0608,
#     'rms': 0.13,
#     'gap': 218,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 6 km SSE of Guánica, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-66.8805, 17.9143, 5]},
#    'id': 'pr2020281021'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.56,
#     'place': '7km NW of The Geysers, CA',
#     'time': 1602110000910,
#     'updated': 1602110095548,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73468011',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73468011.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 5,
#     'net': 'nc',
#     'code': '73468011',
#     'ids': ',nc73468011,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,',
#     'nst': 11,
#     'dmin': 0.0006913,
#     'rms': 0.02,
#     'gap': 88,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.6 - 7km NW of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.8105011, 38.8240013, 1.25]},
#    'id': 'nc73468011'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.8,
#     'place': '16 km N of Willow, Alaska',
#     'time': 1602109955225,
#     'updated': 1602110302012,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020cx3azpe',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak020cx3azpe.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 50,
#     'net': 'ak',
#     'code': '020cx3azpe',
#     'ids': ',ak020cx3azpe,',
#     'sources': ',ak,',
#     'types': ',origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 1.14,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 16 km N of Willow, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-150.0647, 61.891, 71.9]},
#    'id': 'ak020cx3azpe'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': '15 km NNW of Shijak, Albania',
#     'time': 1602108785934,
#     'updated': 1602112543338,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c6kg',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000c6kg.geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 312,
#     'net': 'us',
#     'code': '6000c6kg',
#     'ids': ',us6000c6kg,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': None,
#     'dmin': 0.966,
#     'rms': 0.92,
#     'gap': 49,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.5 - 15 km NNW of Shijak, Albania'},
#    'geometry': {'type': 'Point', 'coordinates': [19.4973, 41.4789, 10]},
#    'id': 'us6000c6kg'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': '287 km E of Levuka, Fiji',
#     'time': 1602108515653,
#     'updated': 1602109613040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000c6kf',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000c6kf.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 312,
#     'net': 'us',
#     'code': '6000c6kf',
#     'ids': ',us6000c6kf,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 3.677,
#     'rms': 0.85,
#     'gap': 41,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.5 - 287 km E of Levuka, Fiji'},
#    'geometry': {'type': 'Point', 'coordinates': [-177.9698, -18.0035, 601.99]},
#    'id': 'us6000c6kf'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.2,
#     'place': '42 km ESE of Cantwell, Alaska',
#     'time': 1602108140783,
#     'updated': 1602109019079,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020cx34j3y',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak020cx34j3y.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 22,
#     'net': 'ak',
#     'code': '020cx34j3y',
#     'ids': ',ak020cx34j3y,',
#     'sources': ',ak,',
#     'types': ',origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.65,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.2 - 42 km ESE of Cantwell, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-148.2406, 63.1901, 10.3]},
#    'id': 'ak020cx34j3y'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.61,
#     'place': '7km S of Mineral, CA',
#     'time': 1602108019990,
#     'updated': 1602113705158,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73467996',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73467996.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 40,
#     'net': 'nc',
#     'code': '73467996',
#     'ids': ',nc73467996,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 10,
#     'dmin': 0.1448,
#     'rms': 0.05,
#     'gap': 129,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 7km S of Mineral, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-121.5521667, 40.2905, 2.95]},
#    'id': 'nc73467996'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.37,
#     'place': '3km S of Home Gardens, CA',
#     'time': 1602108000310,
#     'updated': 1602108247346,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39655960',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39655960.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 29,
#     'net': 'ci',
#     'code': '39655960',
#     'ids': ',ci39655960,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 30,
#     'dmin': 0.07503,
#     'rms': 0.22,
#     'gap': 45,
#     'magType': 'ml',
#     'type': 'quarry blast',
#     'title': 'M 1.4 Quarry Blast - 3km S of Home Gardens, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.5251667, 33.8518333, 0.57]},
#    'id': 'ci39655960'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.94,
#     'place': '20km ESE of Little Lake, CA',
#     'time': 1602107757180,
#     'updated': 1602107974702,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39655944',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39655944.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 14,
#     'net': 'ci',
#     'code': '39655944',
#     'ids': ',ci39655944,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 15,
#     'dmin': 0.07363,
#     'rms': 0.14,
#     'gap': 71,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.9 - 20km ESE of Little Lake, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.7013333, 35.8611667, 6.26]},
#    'id': 'ci39655944'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.56,
#     'place': '7km NW of The Geysers, CA',
#     'time': 1602107659120,
#     'updated': 1602107755652,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73467991',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73467991.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 5,
#     'net': 'nc',
#     'code': '73467991',
#     'ids': ',nc73467991,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,',
#     'nst': 10,
#     'dmin': 0.0007925,
#     'rms': 0.02,
#     'gap': 81,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.6 - 7km NW of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.8098297, 38.8241653, 1.83]},
#    'id': 'nc73467991'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.51,
#     'place': '12km NE of Mammoth Lakes, CA',
#     'time': 1602107498020,
#     'updated': 1602108894007,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73467986',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73467986.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 4,
#     'net': 'nc',
#     'code': '73467986',
#     'ids': ',nc73467986,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,',
#     'nst': 12,
#     'dmin': 0.04229,
#     'rms': 0.06,
#     'gap': 172,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.5 - 12km NE of Mammoth Lakes, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.8706667, 37.7093333, -0.85]},
#    'id': 'nc73467986'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.58,
#     'place': '5km SSE of Home Gardens, CA',
#     'time': 1602107171630,
#     'updated': 1602107414963,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39655920',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39655920.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 38,
#     'net': 'ci',
#     'code': '39655920',
#     'ids': ',ci39655920,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 46,
#     'dmin': 0.05088,
#     'rms': 0.23,
#     'gap': 35,
#     'magType': 'ml',
#     'type': 'quarry blast',
#     'title': 'M 1.6 Quarry Blast - 5km SSE of Home Gardens, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.499, 33.8413333, 2.29]},
#    'id': 'ci39655920'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.8,
#     'place': '52 km WSW of Tatitlek, Alaska',
#     'time': 1602106941210,
#     'updated': 1602107835040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020cx2ro6s',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak020cx2ro6s.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 121,
#     'net': 'ak',
#     'code': '020cx2ro6s',
#     'ids': ',us6000c6kc,ak020cx2ro6s,',
#     'sources': ',us,ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.63,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.8 - 52 km WSW of Tatitlek, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-147.6008, 60.7184, 22.9]},
#    'id': 'ak020cx2ro6s'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.72,
#     'place': '7km NW of The Geysers, CA',
#     'time': 1602106787510,
#     'updated': 1602109205655,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73467981',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73467981.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 46,
#     'net': 'nc',
#     'code': '73467981',
#     'ids': ',nc73467981,',
#     'sources': ',nc,',
#     'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 32,
#     'dmin': 0.001106,
#     'rms': 0.03,
#     'gap': 36,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 7km NW of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.8099976, 38.824501, 1.4]},
#    'id': 'nc73467981'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.72,
#     'place': '9km SE of Cloverdale, CA',
#     'time': 1602106629110,
#     'updated': 1602113825174,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73467976',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73467976.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 46,
#     'net': 'nc',
#     'code': '73467976',
#     'ids': ',nc73467976,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 19,
#     'dmin': 0.06131,
#     'rms': 0.04,
#     'gap': 173,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 9km SE of Cloverdale, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.9428329, 38.7449989, 4.44]},
#    'id': 'nc73467976'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.09,
#     'place': '10km WSW of Anza, CA',
#     'time': 1602106549200,
#     'updated': 1602106768631,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39655896',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39655896.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 18,
#     'net': 'ci',
#     'code': '39655896',
#     'ids': ',ci39655896,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 43,
#     'dmin': 0.03249,
#     'rms': 0.2,
#     'gap': 30,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 10km WSW of Anza, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.7615, 33.511, 4.51]},
#    'id': 'ci39655896'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.9,
#     'place': '28 km S of Mina, Nevada',
#     'time': 1602106168770,
#     'updated': 1602106758734,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00777698',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00777698.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 12,
#     'net': 'nn',
#     'code': '00777698',
#     'ids': ',nn00777698,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 13,
#     'dmin': 0.027,
#     'rms': 0.15,
#     'gap': 155.55,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.9 - 28 km S of Mina, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-118.0495, 38.1413, 1.2]},
#    'id': 'nn00777698'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.36,
#     'place': '13km SSW of Searles Valley, CA',
#     'time': 1602106064600,
#     'updated': 1602106291860,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39655864',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39655864.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 28,
#     'net': 'ci',
#     'code': '39655864',
#     'ids': ',ci39655864,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 19,
#     'dmin': 0.08313,
#     'rms': 0.18,
#     'gap': 147,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.4 - 13km SSW of Searles Valley, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.4748333, 35.6691667, 4.61]},
#    'id': 'ci39655864'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.42,
#     'place': '4km ESE of Westmorland, CA',
#     'time': 1602105871460,
#     'updated': 1602106100929,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39655848',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39655848.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 31,
#     'net': 'ci',
#     'code': '39655848',
#     'ids': ',ci39655848,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 15,
#     'dmin': 0.009188,
#     'rms': 0.26,
#     'gap': 75,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.4 - 4km ESE of Westmorland, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-115.5836667, 33.0291667, 5.02]},
#    'id': 'ci39655848'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.67,
#     'place': '9km SSE of Tehachapi, CA',
#     'time': 1602104608670,
#     'updated': 1602104840716,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39655824',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39655824.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 43,
#     'net': 'ci',
#     'code': '39655824',
#     'ids': ',ci39655824,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 32,
#     'dmin': 0.08677,
#     'rms': 0.19,
#     'gap': 95,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 9km SSE of Tehachapi, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.4168333, 35.0516667, 2.86]},
#    'id': 'ci39655824'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.66,
#     'place': '6 km SSE of Guánica, Puerto Rico',
#     'time': 1602104227410,
#     'updated': 1602106043120,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2020281020',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2020281020.geojson',
#     'felt': 1,
#     'cdi': 2.7,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 109,
#     'net': 'pr',
#     'code': '2020281020',
#     'ids': ',pr2020281020,',
#     'sources': ',pr,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 16,
#     'dmin': 0.0587,
#     'rms': 0.2,
#     'gap': 217,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.7 - 6 km SSE of Guánica, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-66.8906, 17.9175, 6]},
#    'id': 'pr2020281020'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.2,
#     'place': '37 km SE of Mina, Nevada',
#     'time': 1602104018567,
#     'updated': 1602106916824,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00777691',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00777691.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 74,
#     'net': 'nn',
#     'code': '00777691',
#     'ids': ',nn00777691,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 27,
#     'dmin': 0.046,
#     'rms': 0.1135,
#     'gap': 68.96,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.2 - 37 km SE of Mina, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.7729, 38.1872, 3]},
#    'id': 'nn00777691'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.82,
#     'place': '7 km E of Nescatunga, Oklahoma',
#     'time': 1602103405109,
#     'updated': 1602104379402,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ok2020ttdw',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ok2020ttdw.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 51,
#     'net': 'ok',
#     'code': '2020ttdw',
#     'ids': ',ok2020ttdw,',
#     'sources': ',ok,',
#     'types': ',origin,phase-data,',
#     'nst': 94,
#     'dmin': 0.09988040006,
#     'rms': 0.26,
#     'gap': 83,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 7 km E of Nescatunga, Oklahoma'},
#    'geometry': {'type': 'Point', 'coordinates': [-98.068, 36.76416667, 7.14]},
#    'id': 'ok2020ttdw'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.2,
#     'place': '133 km E of McCarthy, Alaska',
#     'time': 1602103014427,
#     'updated': 1602106302571,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020cx250u9',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak020cx250u9.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 22,
#     'net': 'ak',
#     'code': '020cx250u9',
#     'ids': ',ak020cx250u9,',
#     'sources': ',ak,',
#     'types': ',origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.87,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.2 - 133 km E of McCarthy, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-140.4185, 61.4284, 0]},
#    'id': 'ak020cx250u9'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.1,
#     'place': '28 km S of Mina, Nevada',
#     'time': 1602102635640,
#     'updated': 1602103300040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00777686',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00777686.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 19,
#     'net': 'nn',
#     'code': '00777686',
#     'ids': ',nn00777686,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 17,
#     'dmin': 0.063,
#     'rms': 0.33,
#     'gap': 124.64,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 28 km S of Mina, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-118.0475, 38.1422, 0]},
#    'id': 'nn00777686'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.3,
#     'place': '27 km SSE of Mina, Nevada',
#     'time': 1602102425640,
#     'updated': 1602102698303,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00777684',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00777684.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 26,
#     'net': 'nn',
#     'code': '00777684',
#     'ids': ',nn00777684,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 10,
#     'dmin': 0.015,
#     'rms': 0.12,
#     'gap': 116.57,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 27 km SSE of Mina, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-118.0407, 38.1525, 3.1]},
#    'id': 'nn00777684'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.23,
#     'place': '5 km SSE of Guánica, Puerto Rico',
#     'time': 1602101918870,
#     'updated': 1602103475248,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2020281019',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2020281019.geojson',
#     'felt': 1,
#     'cdi': 2.7,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 161,
#     'net': 'pr',
#     'code': '2020281019',
#     'ids': ',pr2020281019,',
#     'sources': ',pr,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 20,
#     'dmin': 0.162,
#     'rms': 0.13,
#     'gap': 201,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.2 - 5 km SSE of Guánica, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-66.8881, 17.9261, 7]},
#    'id': 'pr2020281019'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.6,
#     'place': '27 km SSE of Mina, Nevada',
#     'time': 1602101781529,
#     'updated': 1602104873266,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00777678',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00777678.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 104,
#     'net': 'nn',
#     'code': '00777678',
#     'ids': ',nn00777678,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 28,
#     'dmin': 0.017,
#     'rms': 0.1238,
#     'gap': 72.49,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 27 km SSE of Mina, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-118.0373, 38.148, 2]},
#    'id': 'nn00777678'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.08,
#     'place': '19 km ENE of West Yellowstone, Montana',
#     'time': 1602101556690,
#     'updated': 1602107941840,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uu60413482',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/uu60413482.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 0,
#     'net': 'uu',
#     'code': '60413482',
#     'ids': ',uu60413482,',
#     'sources': ',uu,',
#     'types': ',origin,phase-data,',
#     'nst': 6,
#     'dmin': 0.0541,
#     'rms': 0.13,
#     'gap': 96,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.1 - 19 km ENE of West Yellowstone, Montana'},
#    'geometry': {'type': 'Point', 'coordinates': [-110.8765, 44.7375, 5.38]},
#    'id': 'uu60413482'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.86,
#     'place': '22 km ENE of Ashford, Washington',
#     'time': 1602101213430,
#     'updated': 1602112309810,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uw61691706',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/uw61691706.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 11,
#     'net': 'uw',
#     'code': '61691706',
#     'ids': ',uw61691706,',
#     'sources': ',uw,',
#     'types': ',origin,phase-data,',
#     'nst': 8,
#     'dmin': 0.01936,
#     'rms': 0.06,
#     'gap': 102,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.9 - 22 km ENE of Ashford, Washington'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.783833333333, 46.8691666666667, 0.38]},
#    'id': 'uw61691706'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.78,
#     'place': '10km NW of Pinnacles, CA',
#     'time': 1602101041850,
#     'updated': 1602108064552,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73467956',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73467956.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 49,
#     'net': 'nc',
#     'code': '73467956',
#     'ids': ',nc73467956,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 11,
#     'dmin': 0.04044,
#     'rms': 0.05,
#     'gap': 155,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 10km NW of Pinnacles, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.2121658, 36.605999, 8.54]},
#    'id': 'nc73467956'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.63,
#     'place': '13km SSW of Searles Valley, CA',
#     'time': 1602100925060,
#     'updated': 1602101133593,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39655752',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39655752.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 6,
#     'net': 'ci',
#     'code': '39655752',
#     'ids': ',ci39655752,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 10,
#     'dmin': 0.08406,
#     'rms': 0.13,
#     'gap': 165,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.6 - 13km SSW of Searles Valley, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.4773333, 35.6698333, 3.15]},
#    'id': 'ci39655752'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.17,
#     'place': '19 km ENE of West Yellowstone, Montana',
#     'time': 1602100790000,
#     'updated': 1602105978410,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uu60413467',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/uu60413467.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 21,
#     'net': 'uu',
#     'code': '60413467',
#     'ids': ',uu60413467,',
#     'sources': ',uu,',
#     'types': ',origin,phase-data,',
#     'nst': 14,
#     'dmin': 0.05246,
#     'rms': 0.17,
#     'gap': 90,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.2 - 19 km ENE of West Yellowstone, Montana'},
#    'geometry': {'type': 'Point', 'coordinates': [-110.8855, 44.7421667, 7.22]},
#    'id': 'uu60413467'},
#   {'type': 'Feature',
#    'properties': {'mag': 1,
#     'place': '19 km ENE of West Yellowstone, Montana',
#     'time': 1602100763770,
#     'updated': 1602105698730,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uu60413462',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/uu60413462.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 15,
#     'net': 'uu',
#     'code': '60413462',
#     'ids': ',uu60413462,',
#     'sources': ',uu,',
#     'types': ',origin,phase-data,',
#     'nst': 11,
#     'dmin': 0.05086,
#     'rms': 0.14,
#     'gap': 90,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.0 - 19 km ENE of West Yellowstone, Montana'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-110.8833333, 44.7431667, 6.27]},
#    'id': 'uu60413462'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.95,
#     'place': '19 km ENE of West Yellowstone, Montana',
#     'time': 1602100692680,
#     'updated': 1602105449900,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uu60413457',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/uu60413457.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 58,
#     'net': 'uu',
#     'code': '60413457',
#     'ids': ',uu60413457,',
#     'sources': ',uu,',
#     'types': ',origin,phase-data,',
#     'nst': 16,
#     'dmin': 0.05214,
#     'rms': 0.16,
#     'gap': 63,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.0 - 19 km ENE of West Yellowstone, Montana'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-110.8858333, 44.7426667, 9.81]},
#    'id': 'uu60413457'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.91,
#     'place': '9km SE of Hidden Valley Lake, CA',
#     'time': 1602100638670,
#     'updated': 1602106748428,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73467951',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73467951.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 13,
#     'net': 'nc',
#     'code': '73467951',
#     'ids': ',nc73467951,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 4,
#     'dmin': 0.07589,
#     'rms': 0.02,
#     'gap': 206,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.9 - 9km SE of Hidden Valley Lake, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.4988333, 38.7411667, 11.84]},
#    'id': 'nc73467951'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.72,
#     'place': '75 km E of Saint Croix, U.S. Virgin Islands',
#     'time': 1602100627980,
#     'updated': 1602114348999,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2020281018',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2020281018.geojson',
#     'felt': 1,
#     'cdi': 1,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 213,
#     'net': 'pr',
#     'code': '2020281018',
#     'ids': ',pr2020281018,',
#     'sources': ',pr,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 13,
#     'dmin': 1.8804,
#     'rms': 0.34,
#     'gap': 347,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.7 - 75 km E of Saint Croix, U.S. Virgin Islands'},
#    'geometry': {'type': 'Point', 'coordinates': [-64.0368, 17.6398, 11]},
#    'id': 'pr2020281018'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.5,
#     'place': '13 km W of Dutch Harbor, Alaska',
#     'time': 1602100470940,
#     'updated': 1602114475240,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/av91008723',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/av91008723.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 4,
#     'net': 'av',
#     'code': '91008723',
#     'ids': ',av91008723,',
#     'sources': ',av,',
#     'types': ',origin,phase-data,',
#     'nst': 6,
#     'dmin': None,
#     'rms': 0.09,
#     'gap': 95,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.5 - 13 km W of Dutch Harbor, Alaska'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-166.736833333333, 53.8678333333333, 6.96]},
#    'id': 'av91008723'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.91,
#     'place': '16km SW of Chester, CA',
#     'time': 1602100008630,
#     'updated': 1602105647673,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc71113284',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc71113284.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 13,
#     'net': 'nc',
#     'code': '71113284',
#     'ids': ',nc71113284,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,',
#     'nst': 9,
#     'dmin': 0.1312,
#     'rms': 0.04,
#     'gap': 177,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.9 - 16km SW of Chester, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-121.373, 40.2106667, 3.77]},
#    'id': 'nc71113284'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.71,
#     'place': '8km NNW of Cholame, CA',
#     'time': 1602099789220,
#     'updated': 1602104705235,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73467926',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73467926.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 45,
#     'net': 'nc',
#     'code': '73467926',
#     'ids': ',nc73467926,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 12,
#     'dmin': 0.01851,
#     'rms': 0.05,
#     'gap': 101,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 8km NNW of Cholame, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.3233337, 35.7856674, 3.55]},
#    'id': 'nc73467926'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.43,
#     'place': '6 km E of Maynard, Arkansas',
#     'time': 1602099591280,
#     'updated': 1602105031040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nm60114523',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nm60114523.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 91,
#     'net': 'nm',
#     'code': '60114523',
#     'ids': ',nm60114523,',
#     'sources': ',nm,',
#     'types': ',origin,phase-data,',
#     'nst': 10,
#     'dmin': 0.4465,
#     'rms': 0.14,
#     'gap': 92,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.4 - 6 km E of Maynard, Arkansas'},
#    'geometry': {'type': 'Point', 'coordinates': [-90.8225, 36.4278333, 12.14]},
#    'id': 'nm60114523'},
#   {'type': 'Feature',
#    'properties': {'mag': -0.69,
#     'place': '78 km W of Salamatof, Alaska',
#     'time': 1602099433790,
#     'updated': 1602114194420,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/av91008718',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/av91008718.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 0,
#     'net': 'av',
#     'code': '91008718',
#     'ids': ',av91008718,',
#     'sources': ',av,',
#     'types': ',origin,phase-data,',
#     'nst': 4,
#     'dmin': None,
#     'rms': 0.03,
#     'gap': 165,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M -0.7 - 78 km W of Salamatof, Alaska'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-152.7335, 60.5293333333333, 5.38]},
#    'id': 'av91008718'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.5,
#     'place': '31 km W of Tanana, Alaska',
#     'time': 1602099411587,
#     'updated': 1602102024013,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020cx1jl0w',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak020cx1jl0w.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 35,
#     'net': 'ak',
#     'code': '020cx1jl0w',
#     'ids': ',ak020cx1jl0w,',
#     'sources': ',ak,',
#     'types': ',origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.53,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.5 - 31 km W of Tanana, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-152.7414, 65.169, 11.1]},
#    'id': 'ak020cx1jl0w'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.9,
#     'place': '28 km SSE of Mina, Nevada',
#     'time': 1602098691210,
#     'updated': 1602099898456,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00777675',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00777675.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 12,
#     'net': 'nn',
#     'code': '00777675',
#     'ids': ',nn00777675,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 10,
#     'dmin': 0.021,
#     'rms': 0.09,
#     'gap': 95.49,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.9 - 28 km SSE of Mina, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.9632, 38.1628, 5]},
#    'id': 'nn00777675'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.45,
#     'place': '13km WNW of Anza, CA',
#     'time': 1602098341590,
#     'updated': 1602101520971,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39655664',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39655664.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 3,
#     'net': 'ci',
#     'code': '39655664',
#     'ids': ',ci39655664,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 9,
#     'dmin': 0.03641,
#     'rms': 0.06,
#     'gap': 161,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.5 - 13km WNW of Anza, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.8075, 33.59, 7.06]},
#    'id': 'ci39655664'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.9,
#     'place': '34 km SE of Mina, Nevada',
#     'time': 1602097692899,
#     'updated': 1602100407270,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00777670',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00777670.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 129,
#     'net': 'nn',
#     'code': '00777670',
#     'ids': ',us6000c6j1,nn00777670,',
#     'sources': ',us,nn,',
#     'types': ',origin,phase-data,',
#     'nst': 31,
#     'dmin': 0.028,
#     'rms': 0.1425,
#     'gap': 49.54,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 34 km SE of Mina, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.8375, 38.1702, 8.6]},
#    'id': 'nn00777670'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.3,
#     'place': '6km WSW of Pala, CA',
#     'time': 1602097687620,
#     'updated': 1602097918960,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39655632',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39655632.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 26,
#     'net': 'ci',
#     'code': '39655632',
#     'ids': ',ci39655632,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 23,
#     'dmin': 0.05954,
#     'rms': 0.32,
#     'gap': 77,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 6km WSW of Pala, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.1313333, 33.3363333, 1.57]},
#    'id': 'ci39655632'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.1,
# ...
#     'title': 'M 1.4 - 7km SW of Holtville, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-115.438, 32.777, 12.19]},
#    'id': 'ci39652952'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.8,
#     'place': '20 km SW of Corinne, Utah',
#     'time': 1601878923480,
#     'updated': 1601912363310,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uu60413132',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/uu60413132.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 10,
#     'net': 'uu',
#     'code': '60413132',
#     'ids': ',uu60413132,',
#     'sources': ',uu,',
#     'types': ',origin,phase-data,',
#     'nst': 8,
#     'dmin': 0.09151,
#     'rms': 0.11,
#     'gap': 146,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.8 - 20 km SW of Corinne, Utah'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-112.3088333, 41.4436667, 0.32]},
#    'id': 'uu60413132'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.8,
#     'place': '52 km ENE of Whittier, Alaska',
#     'time': 1601878897746,
#     'updated': 1601879290068,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020ctin0cs',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak020ctin0cs.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 50,
#     'net': 'ak',
#     'code': '020ctin0cs',
#     'ids': ',ak020ctin0cs,',
#     'sources': ',ak,',
#     'types': ',origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 1.13,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 52 km ENE of Whittier, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-147.8236, 60.9774, 22.1]},
#    'id': 'ak020ctin0cs'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.09,
#     'place': '45 km NE of Spencer, Idaho',
#     'time': 1601878576460,
#     'updated': 1601909434810,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/mb80466919',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/mb80466919.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 18,
#     'net': 'mb',
#     'code': '80466919',
#     'ids': ',mb80466919,',
#     'sources': ',mb,',
#     'types': ',origin,phase-data,',
#     'nst': 17,
#     'dmin': 0.143,
#     'rms': 0.26,
#     'gap': 102,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 45 km NE of Spencer, Idaho'},
#    'geometry': {'type': 'Point', 'coordinates': [-111.8593333, 44.694, 7.94]},
#    'id': 'mb80466919'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.75,
#     'place': '5 km S of Indios, Puerto Rico',
#     'time': 1601878316180,
#     'updated': 1601879802871,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2020279003',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2020279003.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 116,
#     'net': 'pr',
#     'code': '2020279003',
#     'ids': ',pr2020279003,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 22,
#     'dmin': 0.0749,
#     'rms': 0.11,
#     'gap': 188,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.8 - 5 km S of Indios, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-66.81, 17.9465, 10]},
#    'id': 'pr2020279003'},
#   {'type': 'Feature',
#    'properties': {'mag': 2,
#     'place': '55 km SSW of Cantwell, Alaska',
#     'time': 1601877734841,
#     'updated': 1601879059426,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020ctiivz3',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak020ctiivz3.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 62,
#     'net': 'ak',
#     'code': '020ctiivz3',
#     'ids': ',ak020ctiivz3,',
#     'sources': ',ak,',
#     'types': ',origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.48,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.0 - 55 km SSW of Cantwell, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.4798, 62.9578, 75.3]},
#    'id': 'ak020ctiivz3'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.07,
#     'place': '11km S of Searles Valley, CA',
#     'time': 1601877535480,
#     'updated': 1601877751834,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39652944',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39652944.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 18,
#     'net': 'ci',
#     'code': '39652944',
#     'ids': ',ci39652944,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 13,
#     'dmin': 0.09279,
#     'rms': 0.18,
#     'gap': 162,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 11km S of Searles Valley, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.416, 35.6715, 0.75]},
#    'id': 'ci39652944'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.52,
#     'place': '3km ENE of Westmorland, CA',
#     'time': 1601877485630,
#     'updated': 1601877713829,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39652936',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39652936.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 36,
#     'net': 'ci',
#     'code': '39652936',
#     'ids': ',ci39652936,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 19,
#     'dmin': 0.007391,
#     'rms': 0.28,
#     'gap': 86,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.5 - 3km ENE of Westmorland, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-115.5863333, 33.0446667, 5.57]},
#    'id': 'ci39652936'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.15,
#     'place': '4km E of Westmorland, CA',
#     'time': 1601877395040,
#     'updated': 1601877621822,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39652928',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39652928.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 20,
#     'net': 'ci',
#     'code': '39652928',
#     'ids': ',ci39652928,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 18,
#     'dmin': 0.0007679,
#     'rms': 0.25,
#     'gap': 55,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.2 - 4km E of Westmorland, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-115.581, 33.0383333, 5.05]},
#    'id': 'ci39652928'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.22,
#     'place': '3km E of Westmorland, CA',
#     'time': 1601877344940,
#     'updated': 1601877556813,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39652920',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39652920.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 23,
#     'net': 'ci',
#     'code': '39652920',
#     'ids': ',ci39652920,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 15,
#     'dmin': 0.003929,
#     'rms': 0.25,
#     'gap': 57,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.2 - 3km E of Westmorland, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-115.5865, 33.0375, 5]},
#    'id': 'ci39652920'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.3,
#     'place': '29 km SSE of Mina, Nevada',
#     'time': 1601877327240,
#     'updated': 1601877592959,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00777160',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00777160.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 26,
#     'net': 'nn',
#     'code': '00777160',
#     'ids': ',nn00777160,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 19,
#     'dmin': 0.024,
#     'rms': 0.11,
#     'gap': 76.2,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 29 km SSE of Mina, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-118.001, 38.1428, 1.1]},
#    'id': 'nn00777160'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.2,
#     'place': '28 km SSE of Mina, Nevada',
#     'time': 1601877193790,
#     'updated': 1601877392024,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00777157',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00777157.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 1,
#     'net': 'nn',
#     'code': '00777157',
#     'ids': ',nn00777157,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 11,
#     'dmin': 0.029,
#     'rms': 0.06,
#     'gap': 108.37,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.2 - 28 km SSE of Mina, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.9538, 38.1653, 6.9]},
#    'id': 'nn00777157'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.61,
#     'place': '22km WNW of Searles Valley, CA',
#     'time': 1601877190340,
#     'updated': 1601907014056,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39652912',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39652912.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 6,
#     'net': 'ci',
#     'code': '39652912',
#     'ids': ',ci39652912,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 8,
#     'dmin': 0.03084,
#     'rms': 0.07,
#     'gap': 133,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.6 - 22km WNW of Searles Valley, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.6353333, 35.8133333, 7.27]},
#    'id': 'ci39652912'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.9,
#     'place': '18 km SSE of Waynoka, Oklahoma',
#     'time': 1601876959589,
#     'updated': 1601992407942,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ok2020tojj',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ok2020tojj.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 12,
#     'net': 'ok',
#     'code': '2020tojj',
#     'ids': ',ok2020tojj,',
#     'sources': ',ok,',
#     'types': ',origin,phase-data,',
#     'nst': 25,
#     'dmin': 0.02069593875,
#     'rms': 0.08,
#     'gap': 147,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.9 - 18 km SSE of Waynoka, Oklahoma'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-98.78683333, 36.43283333, 8.31]},
#    'id': 'ok2020tojj'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.4,
#     'place': '35 km SE of Mina, Nevada',
#     'time': 1601876900530,
#     'updated': 1601877291571,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00777156',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00777156.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 2,
#     'net': 'nn',
#     'code': '00777156',
#     'ids': ',nn00777156,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 9,
#     'dmin': 0.048,
#     'rms': 0.06,
#     'gap': 115.15,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.4 - 35 km SE of Mina, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.7877, 38.194, 9.8]},
#    'id': 'nn00777156'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.89,
#     'place': 'Puerto Rico region',
#     'time': 1601876488450,
#     'updated': 1601878125302,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2020279002',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2020279002.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 55,
#     'net': 'pr',
#     'code': '2020279002',
#     'ids': ',pr2020279002,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 13,
#     'dmin': 0.027,
#     'rms': 0.13,
#     'gap': 157,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.9 - Puerto Rico region'},
#    'geometry': {'type': 'Point', 'coordinates': [-67.0191, 17.9793, 5]},
#    'id': 'pr2020279002'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.9,
#     'place': '26 km SSE of Mina, Nevada',
#     'time': 1601876365730,
#     'updated': 1601877012652,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00777152',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00777152.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 12,
#     'net': 'nn',
#     'code': '00777152',
#     'ids': ',nn00777152,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 15,
#     'dmin': 0.033,
#     'rms': 0.17,
#     'gap': 92.55,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.9 - 26 km SSE of Mina, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-118.0167, 38.163, 0.2]},
#    'id': 'nn00777152'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.78,
#     'place': '6km NW of The Geysers, CA',
#     'time': 1601875258260,
#     'updated': 1601876165509,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73466761',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73466761.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 9,
#     'net': 'nc',
#     'code': '73466761',
#     'ids': ',nc73466761,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 19,
#     'dmin': 0.01203,
#     'rms': 0.02,
#     'gap': 51,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.8 - 6km NW of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.7945023, 38.8199997, 2.85]},
#    'id': 'nc73466761'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.5,
#     'place': '36 km W of Clear, Alaska, Alaska',
#     'time': 1601874986909,
#     'updated': 1601877916814,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak020cti0hbu',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak020cti0hbu.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 35,
#     'net': 'ak',
#     'code': '020cti0hbu',
#     'ids': ',ak020cti0hbu,',
#     'sources': ',ak,',
#     'types': ',origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.33,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.5 - 36 km W of Clear, Alaska, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.934, 64.2819, 15.9]},
#    'id': 'ak020cti0hbu'},
#   ...],
#  'bbox': [-179.268, -62.3735, -3.5, 178.9776, 69.4466, 628.77]}
